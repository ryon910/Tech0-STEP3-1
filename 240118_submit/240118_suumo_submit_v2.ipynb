# %%
#最低限必要な情報:物件名・住所・間取り・家賃・階数
#希望条件：都内で利便性の高い場所・予算20万円程度・2人暮らし2K以上
#検索条件：JR山手線沿線・予算25万円以下・2K以上の間取り

# %%
# STEP１：全ページの物件情報を全て取ってくる

# 必要なライブラリのインポート
from bs4 import BeautifulSoup
import pandas as pd
import requests
import time
from tqdm import tqdm #for文の進捗確認

# 最後のページの数値を取得する
root_url = 'https://suumo.jp/jj/chintai/ichiran/FR301FC001/?fw2=&mt=9999999&cn=9999999&co=1&ra=013&et=9999999&shkr1=03&ar=030&bs=040&ct=25.0&shkr3=03&shkr2=03&mb=0&md=05&md=06&md=07&md=08&md=09&md=10&md=11&md=12&md=13&md=14&rn=0005&shkr4=03&cb=0.0&page={}'
res = requests.get(root_url.format(1))
res.encoding = 'utf-8'
soup = BeautifulSoup(res.text, 'html.parser')
total_page = int(soup.find('ol', class_='pagination-parts').find_all('li')[-1].text)

#物件情報を1件ずつ格納するための空のリストを用意しておく
d_list = []

# 正常にHTMLの情報が取得できれば以下のコードを実行
if res.status_code == 200:

    # 物件一覧ページをfor文で1ページずつループ
    for i in tqdm(range(1, total_page+1)):
        root_url = 'https://suumo.jp/jj/chintai/ichiran/FR301FC001/?fw2=&mt=9999999&cn=9999999&co=1&ra=013&et=9999999&shkr1=03&ar=030&bs=040&ct=25.0&shkr3=03&shkr2=03&mb=0&md=05&md=06&md=07&md=08&md=09&md=10&md=11&md=12&md=13&md=14&rn=0005&shkr4=03&cb=0.0&page={}'
        res = requests.get(root_url.format(i))
        res.encoding = 'utf-8'
        soup = BeautifulSoup(res.text, 'html.parser')
        time.sleep(1)

        # 物件一覧ページの物件情報をfor文で1件ずつループ
        contents = soup.find_all('div', class_='cassetteitem')
        for content in contents:

            # 物件情報をdetailに格納する
            detail = content.find('div', class_='cassetteitem-detail')
            # 物件名
            name = detail.find('div', class_='cassetteitem_content-title').text
            # 住所
            address = detail.find('li', class_='cassetteitem_detail-col1').text
            # アクセス
            access1 = detail.find_all('div', class_='cassetteitem_detail-text')[0].text
            access2 = detail.find_all('div', class_='cassetteitem_detail-text')[1].text
            access3 = detail.find_all('div', class_='cassetteitem_detail-text')[2].text
            # 築年数/構造
            age = detail.find('li', class_='cassetteitem_detail-col3').find_all('div')[0].text
            structure = detail.find('li', class_='cassetteitem_detail-col3').find_all('div')[1].text
            # 物件画像リンク
            try:
                build_img_url = detail.find('img', class_='js-linkImage').get('rel')
            except Exception as e:
                build_img_url = None

            # 物件情報の中で、部屋情報をfor文で1件ずつループ
            table = content.find('table', class_='cassetteitem_other')
            tr_tags = table.find_all('tr', class_='js-cassette_link')
            for tr_tag in tr_tags:

                # 部屋情報
                floor, price, first_fee, capacity = tr_tag.find_all('td')[2:6]
                floor = floor.text.replace('\r','').replace('\n','').replace('\t','')
                rent, admin = price.find_all('li')
                deposit, gratuity = first_fee.find_all('li')
                madori, menseki = capacity.find_all('li')
                madori_img_url = tr_tags[0].find_all('td')[1].find('img').get('rel')
                detail_url = 'https://suumo.jp' + tr_tag.find_all('td')[8].find('a').get('href')

                # １つの部屋情報をまとめて辞書dに格納
                d = {
                    'name':name,
                    'address':address,
                    'access1':access1,
                    'access2':access2,
                    'access3':access3,
                    'age':age,
                    'structure':structure,
                    'build_img_url':build_img_url,
                    'floor':floor,
                    'rent':rent.text,
                    'admin':admin.text,
                    'deposit':deposit.text,
                    'gratuity':gratuity.text,
                    'madori':madori.text,
                    'menseki':menseki.text,
                    'madori_img_url':madori_img_url,
                    'detail_url':detail_url,
                }

                # 部屋情報をd_listに1件ずつ追加
                d_list.append(d)

#完成したリストはDataFrameに格納
df = pd.DataFrame(d_list)
# Out:
# 100%|██████████| 76/76 [02:38<00:00,  2.09s/it]

# %%
df.isnull().any()
# Out:
# name              False
# address           False
# access1           False
# access2           False
# access3           False
# age               False
# structure         False
# build_img_url      True
# floor             False
# rent              False
# admin             False
# deposit           False
# gratuity          False
# madori            False
# menseki           False
# madori_img_url    False
# detail_url        False
# dtype: bool

# %%
#STEP2：データクレンジング

#アクセスから路線・駅名・徒歩時間を抽出。.str.split()で分割しても良い。
df[['access1_line', 'access1_station', 'access1_walk']] = df['access1'].str.extract(r'(.+?)/(.+?) 歩(.+?)分')
df[['access2_line', 'access2_station', 'access2_walk']] = df['access2'].str.extract(r'(.+?)/(.+?) 歩(.+?)分')
df[['access3_line', 'access3_station', 'access3_walk']] = df['access3'].str.extract(r'(.+?)/(.+?) 歩(.+?)分')

# addressカラムの各要素に対して末尾が1〜9であれば「丁目」を結合する。後々geopyを適用して、緯度経度の情報を取得するために必要。
df['address'] = df['address'].apply(lambda x: x + '丁目' if x[-1] in '１２３４５６７８９' else x)

#ageを質的データから量的データ（比例尺度）に変換。99年以上は99に集約。
df['age'] = df['age'].str.replace('新築', '築0年').str.replace('築','').str.replace('年','').str.replace('以上','').astype(int)

#お金（rent, admin, deposit, gratuity）のデータ（比例尺度）に変換
def extract_amount(text):
    try:
        if '-' in text:
            amount = 0
        elif '万円' in text:
            # '万円' を削除して、float型に変換してから10000倍する
            amount = float(text.replace('万円', '')) * 10000
        else:
            # '円' を削除して、float型に変換
            amount = float(text.replace('円', ''))
    except ValueError:
        amount = None
    return int(amount)
df['rent'] = df['rent'].apply(extract_amount)
df['admin'] = df['admin'].apply(extract_amount)
df['deposit'] = df['deposit'].apply(extract_amount)
df['gratuity'] = df['gratuity'].apply(extract_amount)

#mensekiのデータ（比例尺度）に変換
df['menseki'] = df['menseki'].str.replace('m2','').astype(float)

#structure, floorのデータの表現を統一
df['structure'] = df['structure'].str.replace('地下', 'B').str.replace('地上', '-').str.replace('平屋', '1階建').str.replace('階建', 'F')
df['floor'] = df['floor'].str.replace('階', '')

#欠損値を'-'で埋める
df = df.fillna('-')

#不要なカラムを削除
df = df.drop(columns=['access1','access2','access3'])

#name, address, floor, rent, madoriが一致する物件を重複排除
df = df.drop_duplicates(subset=['name','address', 'floor', 'rent', 'madori'])

# %%
df.shape
# Out:
# (3042, 23)

# %%
#STEP3:geopyで住所から緯度経度の情報を取得し、dfに結合
from geopy.geocoders import Nominatim
import pandas as pd
import tqdm

geolocator = Nominatim(user_agent="suumo", timeout=10)

# 住所データ
addresses = df['address']

# 緯度経度に変換。取得できない場合は（None, None）とする。
latitudes = []
longitudes = []
for address in tqdm.tqdm(addresses):
    try:
        location = geolocator.geocode(address)
        if location:
            latitudes.append(location.latitude)
            longitudes.append(location.longitude)
        else:
            latitudes.append(None)
            longitudes.append(None)
    except Exception as e:
        latitudes.append(None)
        longitudes.append(None)
        print(f"Error geocoding {address}: {e}")

# 緯度・経度の情報を元のdfに追加する。
df['latitude'] = latitudes
df['longitude'] = longitudes
# Out:
# 100%|██████████| 3042/3042 [35:17<00:00,  1.44it/s]

# %%
df.head()
# Out:
#                   name        address  age structure  \
# 0               第六田嶋ビル    東京都北区東田端２丁目   21        3F
# 1            山口貸戸建アパート  東京都荒川区西日暮里４丁目   47        2F
# 2            山口貸戸建アパート  東京都荒川区西日暮里４丁目   47        2F
# 3                 横山貸家  東京都荒川区西日暮里４丁目   77        2F
# 4  ＪＲ山手線 駒込駅 14階建 築10年     東京都北区田端３丁目   10       14F
#
#                                        build_img_url floor    rent  admin  \
# 0  https://img01.suumo.com/front/gazo/fr/bukken/9...     2  112000   5000
# 1  https://img01.suumo.com/front/gazo/fr/bukken/9...   1-2   95000      0
# 2  https://img01.suumo.com/front/gazo/fr/bukken/9...     1   95000   5500
# 3  https://img01.suumo.com/front/gazo/fr/bukken/9...     1  200000      0
# 4  https://img01.suumo.com/front/gazo/fr/bukken/1...     4  168000  10000
#
#    deposit  gratuity  ... access1_station  access1_walk access2_line  \
# 0   112000    112000  ...             田端駅           5.0      ＪＲ京浜東北線
# 1    95000     95000  ...           西日暮里駅           4.0        ＪＲ山手線
# 2    95000     95000  ...           西日暮里駅           4.0        ＪＲ山手線
# 3   200000    200000  ...             田端駅           8.0    東京メトロ千代田線
# 4   168000    168000  ...             駒込駅           5.0        ＪＲ山手線
#
#   access2_station access2_walk access3_line access3_station access3_walk  \
# 0           西日暮里駅         13.0   日暮里・舎人ライナー         赤土小学校前駅         11.0
# 1             田端駅          6.0        ＪＲ山手線            日暮里駅         15.0
# 2             田端駅          6.0        ＪＲ山手線            日暮里駅         15.0
# 3           西日暮里駅          7.0        ＪＲ山手線            日暮里駅         16.0
# 4             田端駅         15.0        都営三田線             巣鴨駅         19.0
#
#     latitude   longitude
# 0  35.740101  139.760583
# 1  35.732731  139.763707
# 2  35.732731  139.763707
# 3  35.732731  139.763707
# 4  35.740101  139.760583
#
# [5 rows x 25 columns]

# %%
df[['address', 'latitude', 'longitude']].query('latitude != latitude')
# Out:
#             address  latitude  longitude
# 66     神奈川県横浜市磯子区上町       NaN        NaN
# 327     東京都目黒区三田１丁目       NaN        NaN
# 418     東京都目黒区三田２丁目       NaN        NaN
# 419     東京都目黒区三田２丁目       NaN        NaN
# 457     東京都台東区三筋２丁目       NaN        NaN
# 458     東京都台東区三筋２丁目       NaN        NaN
# 459     東京都台東区三筋２丁目       NaN        NaN
# 460     東京都台東区三筋２丁目       NaN        NaN
# 462     東京都台東区三筋２丁目       NaN        NaN
# 899    東京都中央区八丁堀３丁目       NaN        NaN
# 993    東京都八王子市上壱分方町       NaN        NaN
# 1205     東京都港区三田５丁目       NaN        NaN
# 1366     東京都港区三田２丁目       NaN        NaN
# 1416     東京都港区三田５丁目       NaN        NaN
# 1495    東京都品川区八潮５丁目       NaN        NaN
# 1496    東京都品川区八潮５丁目       NaN        NaN
# 1497    東京都品川区八潮５丁目       NaN        NaN
# 1498    東京都品川区八潮５丁目       NaN        NaN
# 1513    東京都品川区八潮５丁目       NaN        NaN
# 1514    東京都品川区八潮５丁目       NaN        NaN
# 1515    東京都品川区八潮５丁目       NaN        NaN
# 1631    東京都台東区三筋２丁目       NaN        NaN
# 1632    東京都台東区三筋２丁目       NaN        NaN
# 1876    東京都台東区三筋１丁目       NaN        NaN
# 1982     東京都港区三田２丁目       NaN        NaN
# 2057   東京都台東区三ノ輪１丁目       NaN        NaN
# 2199   東京都台東区三ノ輪１丁目       NaN        NaN
# 2258   東京都中央区八丁堀３丁目       NaN        NaN
# 2259   東京都中央区八丁堀３丁目       NaN        NaN
# 2288   東京都中央区八丁堀３丁目       NaN        NaN
# 2375     東京都港区三田４丁目       NaN        NaN
# 2385   東京都中央区八丁堀３丁目       NaN        NaN
# 2386   東京都中央区八丁堀３丁目       NaN        NaN
# 2387   東京都中央区八丁堀３丁目       NaN        NaN
# 2409    東京都台東区三筋２丁目       NaN        NaN
# 2437   東京都中央区八丁堀３丁目       NaN        NaN
# 2626  千葉県松戸市三矢小台１丁目       NaN        NaN
# 2632   東京都台東区三ノ輪１丁目       NaN        NaN
# 2661    東京都台東区三筋２丁目       NaN        NaN
# 2675     東京都港区三田５丁目       NaN        NaN
# 2781   東京都台東区三ノ輪１丁目       NaN        NaN
# 2960   東京都中央区八丁堀４丁目       NaN        NaN
# 2989     東京都港区三田５丁目       NaN        NaN
# 3048   東京都中央区八丁堀３丁目       NaN        NaN
# 3049   東京都中央区八丁堀３丁目       NaN        NaN
# 3097     東京都港区三田５丁目       NaN        NaN
# 3134   東京都中央区八丁堀３丁目       NaN        NaN
# 3207     東京都港区三田５丁目       NaN        NaN
# 3282    東京都目黒区八雲４丁目       NaN        NaN
# 3306     東京都港区三田２丁目       NaN        NaN

# %%
df = df.reset_index()
df = df.rename(columns={'index':'id'})

# %%
df = df[['id', 'name', 'address', 'age', 'structure', 'floor', 'rent','admin', 'deposit', 'gratuity', 'madori', 'menseki',
        'access1_line', 'access1_station', 'access1_walk','access2_line', 'access2_station', 'access2_walk', 'access3_line',
        'access3_station', 'access3_walk','latitude', 'longitude','build_img_url','madori_img_url','detail_url']]

# %%
df.head()
# Out:
#    id                 name        address  age structure floor    rent  admin  \
# 0   0               第六田嶋ビル    東京都北区東田端２丁目   21        3F     2  112000   5000
# 1   1            山口貸戸建アパート  東京都荒川区西日暮里４丁目   47        2F   1-2   95000      0
# 2   2            山口貸戸建アパート  東京都荒川区西日暮里４丁目   47        2F     1   95000   5500
# 3   3                 横山貸家  東京都荒川区西日暮里４丁目   77        2F     1  200000      0
# 4   4  ＪＲ山手線 駒込駅 14階建 築10年     東京都北区田端３丁目   10       14F     4  168000  10000
#
#    deposit  gratuity  ... access2_station  access2_walk access3_line  \
# 0   112000    112000  ...           西日暮里駅          13.0   日暮里・舎人ライナー
# 1    95000     95000  ...             田端駅           6.0        ＪＲ山手線
# 2    95000     95000  ...             田端駅           6.0        ＪＲ山手線
# 3   200000    200000  ...           西日暮里駅           7.0        ＪＲ山手線
# 4   168000    168000  ...             田端駅          15.0        都営三田線
#
#   access3_station access3_walk   latitude   longitude  \
# 0         赤土小学校前駅         11.0  35.740101  139.760583
# 1            日暮里駅         15.0  35.732731  139.763707
# 2            日暮里駅         15.0  35.732731  139.763707
# 3            日暮里駅         16.0  35.732731  139.763707
# 4             巣鴨駅         19.0  35.740101  139.760583
#
#                                        build_img_url  \
# 0  https://img01.suumo.com/front/gazo/fr/bukken/9...
# 1  https://img01.suumo.com/front/gazo/fr/bukken/9...
# 2  https://img01.suumo.com/front/gazo/fr/bukken/9...
# 3  https://img01.suumo.com/front/gazo/fr/bukken/9...
# 4  https://img01.suumo.com/front/gazo/fr/bukken/1...
#
#                                       madori_img_url  \
# 0  https://img01.suumo.com/front/gazo/fr/bukken/9...
# 1  https://img01.suumo.com/front/gazo/fr/bukken/1...
# 2  https://img01.suumo.com/front/gazo/fr/bukken/1...
# 3  https://img01.suumo.com/front/gazo/fr/bukken/9...
# 4  https://img01.suumo.com/front/gazo/fr/bukken/1...
#
#                                           detail_url
# 0  https://suumo.jp/chintai/jnc_000042321524/?bc=...
# 1  https://suumo.jp/chintai/jnc_000087349489/?bc=...
# 2  https://suumo.jp/chintai/jnc_000087389395/?bc=...
# 3  https://suumo.jp/chintai/jnc_000087761513/?bc=...
# 4  https://suumo.jp/chintai/jnc_000087768246/?bc=...
#
# [5 rows x 26 columns]

# %%
# STEP4：dfをRDBのSQLiteに書き込む
#必要なライブラリのインポート
import sqlite3
# databaseに接続する。指定したdatabaseが存在しない場合は、新規作成される。
conn = sqlite3.connect('suumo_v2.db')
# 物件情報が入ったdfをsqlに書き出す。
df.to_sql('suumo_v2', conn, if_exists='replace', index=False)

# databaseをクエリで実行した結果を読み込み、df_from_sqliteに代入。printで書き込み結果を確認する。
query = "SELECT * FROM suumo_v2"
df_from_sqlite = pd.read_sql(query, conn)
print(df_from_sqlite)

#databaseとの接続を終了
conn.close()
# Out:
#         id                 name        address  age structure floor    rent  \
# 0        0               第六田嶋ビル    東京都北区東田端２丁目   21        3F     2  112000
# 1        1            山口貸戸建アパート  東京都荒川区西日暮里４丁目   47        2F   1-2   95000
# 2        2            山口貸戸建アパート  東京都荒川区西日暮里４丁目   47        2F     1   95000
# 3        3                 横山貸家  東京都荒川区西日暮里４丁目   77        2F     1  200000
# 4        4  ＪＲ山手線 駒込駅 14階建 築10年     東京都北区田端３丁目   10       14F     4  168000
# ...    ...                  ...            ...  ...       ...   ...     ...
# 3037  3037          Ｈａｌｅ　Ｎａｎａｌａ   東京都豊島区南池袋３丁目    0        3F     1  203000
# 3038  3038          Ｈａｌｅ　Ｎａｎａｌａ   東京都豊島区南池袋３丁目    0        3F     1  209000
# 3039  3039     ＪＲ山手線 池袋駅 3階建 新築   東京都豊島区南池袋３丁目    0        3F     1  203000
# 3040  3040     ＪＲ山手線 池袋駅 3階建 新築   東京都豊島区南池袋３丁目    0        3F     1  209000
# 3041  3041            アルカディア恵比寿   東京都渋谷区恵比寿３丁目    0        3F     3  238000
#
#       admin  deposit  gratuity  ... access2_station  access2_walk  \
# 0      5000   112000    112000  ...           西日暮里駅          13.0
# 1         0    95000     95000  ...             田端駅           6.0
# 2      5500    95000     95000  ...             田端駅           6.0
# 3         0   200000    200000  ...           西日暮里駅           7.0
# 4     10000   168000    168000  ...             田端駅          15.0
# ...     ...      ...       ...  ...             ...           ...
# 3037   6500   203000    304500  ...            東池袋駅           8.0
# 3038   6500   209000    313500  ...            東池袋駅           8.0
# 3039   6500   203000    304500  ...            東池袋駅           8.0
# 3040   6500   209000    313500  ...            東池袋駅           8.0
# 3041   5000   238000    238000  ...            白金台駅          13.0
#
#      access3_line access3_station access3_walk   latitude   longitude  \
# 0      日暮里・舎人ライナー         赤土小学校前駅         11.0  35.740101  139.760583
# 1           ＪＲ山手線            日暮里駅         15.0  35.732731  139.763707
# 2           ＪＲ山手線            日暮里駅         15.0  35.732731  139.763707
# 3           ＪＲ山手線            日暮里駅         16.0  35.732731  139.763707
# 4           都営三田線             巣鴨駅         19.0  35.740101  139.760583
# ...           ...             ...          ...        ...         ...
# 3037    東京メトロ副都心線           雑司が谷駅         10.0  35.724315  139.714282
# 3038    東京メトロ副都心線           雑司が谷駅         10.0  35.724315  139.714282
# 3039    東京メトロ副都心線           雑司が谷駅         10.0  35.724315  139.714282
# 3040    東京メトロ副都心線           雑司が谷駅         10.0  35.724315  139.714282
# 3041    東京メトロ日比谷線             広尾駅         15.0  35.643589  139.718513
#
#                                           build_img_url  \
# 0     https://img01.suumo.com/front/gazo/fr/bukken/9...
# 1     https://img01.suumo.com/front/gazo/fr/bukken/9...
# 2     https://img01.suumo.com/front/gazo/fr/bukken/9...
# 3     https://img01.suumo.com/front/gazo/fr/bukken/9...
# 4     https://img01.suumo.com/front/gazo/fr/bukken/1...
# ...                                                 ...
# 3037  https://img01.suumo.com/front/gazo/fr/bukken/0...
# 3038  https://img01.suumo.com/front/gazo/fr/bukken/0...
# 3039  https://img01.suumo.com/front/gazo/fr/bukken/1...
# 3040  https://img01.suumo.com/front/gazo/fr/bukken/1...
# 3041  https://img01.suumo.com/front/gazo/fr/bukken/0...
#
#                                          madori_img_url  \
# 0     https://img01.suumo.com/front/gazo/fr/bukken/9...
# 1     https://img01.suumo.com/front/gazo/fr/bukken/1...
# 2     https://img01.suumo.com/front/gazo/fr/bukken/1...
# 3     https://img01.suumo.com/front/gazo/fr/bukken/9...
# 4     https://img01.suumo.com/front/gazo/fr/bukken/1...
# ...                                                 ...
# 3037  https://img01.suumo.com/front/gazo/fr/bukken/6...
# 3038  https://img01.suumo.com/front/gazo/fr/bukken/6...
# 3039  https://img01.suumo.com/front/gazo/fr/bukken/1...
# 3040  https://img01.suumo.com/front/gazo/fr/bukken/1...
# 3041  https://img01.suumo.com/front/gazo/fr/bukken/0...
#
#                                              detail_url
# 0     https://suumo.jp/chintai/jnc_000042321524/?bc=...
# 1     https://suumo.jp/chintai/jnc_000087349489/?bc=...
# 2     https://suumo.jp/chintai/jnc_000087389395/?bc=...
# 3     https://suumo.jp/chintai/jnc_000087761513/?bc=...
# 4     https://suumo.jp/chintai/jnc_000087768246/?bc=...
# ...                                                 ...
# 3037  https://suumo.jp/chintai/jnc_000086992669/?bc=...
# 3038  https://suumo.jp/chintai/jnc_000086992668/?bc=...
# 3039  https://suumo.jp/chintai/jnc_000086992675/?bc=...
# 3040  https://suumo.jp/chintai/jnc_000086992674/?bc=...
# 3041  https://suumo.jp/chintai/jnc_000086930799/?bc=...
#
# [3042 rows x 26 columns]

# %%
df.dtypes
# Out:
# name                object
# address             object
# age                  int64
# structure           object
# build_img_url       object
# floor               object
# rent                 int64
# admin                int64
# deposit              int64
# gratuity             int64
# madori              object
# menseki            float64
# madori_img_url      object
# detail_url          object
# access1_line        object
# access1_station     object
# access1_walk        object
# access2_line        object
# access2_station     object
# access2_walk        object
# access3_line        object
# access3_station     object
# access3_walk        object
# latitude           float64
# longitude          float64
# dtype: object

# %%
df.head()
# Out:
#                   name        address  age structure floor    rent  admin  \
# 0               第六田嶋ビル    東京都北区東田端２丁目   21        3F     2  112000   5000
# 1            山口貸戸建アパート  東京都荒川区西日暮里４丁目   47        2F   1-2   95000      0
# 2            山口貸戸建アパート  東京都荒川区西日暮里４丁目   47        2F     1   95000   5500
# 3                 横山貸家  東京都荒川区西日暮里４丁目   77        2F     1  200000      0
# 4  ＪＲ山手線 駒込駅 14階建 築10年     東京都北区田端３丁目   10       14F     4  168000  10000
#
#    deposit  gratuity madori  ...  access2_station access2_walk access3_line  \
# 0   112000    112000     2K  ...            西日暮里駅         13.0   日暮里・舎人ライナー
# 1    95000     95000     3K  ...              田端駅          6.0        ＪＲ山手線
# 2    95000     95000     3K  ...              田端駅          6.0        ＪＲ山手線
# 3   200000    200000   3LDK  ...            西日暮里駅          7.0        ＪＲ山手線
# 4   168000    168000   2LDK  ...              田端駅         15.0        都営三田線
#
#   access3_station access3_walk   latitude   longitude  \
# 0         赤土小学校前駅         11.0  35.740101  139.760583
# 1            日暮里駅         15.0  35.732731  139.763707
# 2            日暮里駅         15.0  35.732731  139.763707
# 3            日暮里駅         16.0  35.732731  139.763707
# 4             巣鴨駅         19.0  35.740101  139.760583
#
#                                        build_img_url  \
# 0  https://img01.suumo.com/front/gazo/fr/bukken/9...
# 1  https://img01.suumo.com/front/gazo/fr/bukken/9...
# 2  https://img01.suumo.com/front/gazo/fr/bukken/9...
# 3  https://img01.suumo.com/front/gazo/fr/bukken/9...
# 4  https://img01.suumo.com/front/gazo/fr/bukken/1...
#
#                                       madori_img_url  \
# 0  https://img01.suumo.com/front/gazo/fr/bukken/9...
# 1  https://img01.suumo.com/front/gazo/fr/bukken/1...
# 2  https://img01.suumo.com/front/gazo/fr/bukken/1...
# 3  https://img01.suumo.com/front/gazo/fr/bukken/9...
# 4  https://img01.suumo.com/front/gazo/fr/bukken/1...
#
#                                           detail_url
# 0  https://suumo.jp/chintai/jnc_000042321524/?bc=...
# 1  https://suumo.jp/chintai/jnc_000087349489/?bc=...
# 2  https://suumo.jp/chintai/jnc_000087389395/?bc=...
# 3  https://suumo.jp/chintai/jnc_000087761513/?bc=...
# 4  https://suumo.jp/chintai/jnc_000087768246/?bc=...
#
# [5 rows x 25 columns]
